# %%
from pathlib import Path

# =========================
# 1. 텍스트 데이터 준비
# =========================
path = Path("./data/The Old Man and The Sea.txt")

if not path.exists():
    path = Path("The Old Man and The Sea.txt")

text = path.read_text(encoding="utf-8")

# print("전체 글자 수:", len(text))
# Out:
# 원본 텍스트:
#
# * A Project Gutenberg Canada Ebook *
#
# This ebook is made available at no cost and with very few
# res
#
# encode 결과:
# [0, 8, 1, 24, 1, 39, 69, 66, 61, 56, 54, 71, 1, 30, 72, 71, 56, 65, 53, 56, 69, 58, 1, 26, 52, 65, 52, 55, 52, 1, 28, 53, 66, 66, 62, 1, 8, 0, 0, 43, 59, 60, 70, 1, 56, 53, 66, 66, 62, 1, 60, 70, 1, 64, 52, 55, 56, 1, 52, 73, 52, 60, 63, 52, 53, 63, 56, 1, 52, 71, 1, 65, 66, 1, 54, 66, 70, 71, 1, 52, 65, 55, 1, 74, 60, 71, 59, 1, 73, 56, 69, 76, 1, 57, 56, 74, 0, 69, 56, 70]
#
# decode 결과:
#
# * A Project Gutenberg Canada Ebook *
#
# This ebook is made available at no cost and with very few
# res

# %%
# 2단계. 문자 단위 Tokenization
